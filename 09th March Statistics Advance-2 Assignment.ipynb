# %%
#Statistics Advance-2 Assignment
"""Q1: What are the Probability Mass Function (PMF) and Probability Density Function (PDF)? Explain with
an example."""
Ans:  Probability Mass Function (PMF) is a function that gives the probability of a discrete random variable taking on a 
particular value. For example, if we have a coin toss experiment, the PMF would tell us the probability of getting heads or 
tails. 

Probability Density Function (PDF) is a function that gives the probability of a continuous random variable taking on a 
particular value. For example, if we have a normal distribution, the PDF would tell us the probability of getting any value
within the range of the distribution.

Both PMF and PDF are used to describe the probability of a random variable taking on a particular value.

"""Q2: What is Cumulative Density Function (CDF)? Explain with an example. Why CDF is used?"""
Ans: Cumulative Density Function (CDF) is a function that gives the probability that a random variable is less than or equal to 
a certain value. It is used to describe the probability distribution of a continuous random variable. 

For example, if we have a continuous random variable X with a probability density function (PDF) f(x), then the CDF of X is 
defined as F(x) = P(X ≤ x).

CDF is used to determine the probability that a random variable will take on a value less than or equal to a given value. It 
is also used to compare the probability distributions of two or more random variables. Additionally, it can be used to 
calculate the expected value of a random variable.

"""Q3: What are some examples of situations where the normal distribution might be used as a model?
Explain how the parameters of the normal distribution relate to the shape of the distribution."""
Ans: Examples of situations where the normal distribution might be used as a model include: 
1. Measuring the heights of people in a population. 
2. Measuring the IQ scores of students in a school. 
3. Measuring the amount of rainfall in a region over a period of time. 

The parameters of the normal distribution relate to the shape of the distribution in that they determine the mean, variance, 
and standard deviation of the data. The mean is the center of the distribution and determines where most of the data points 
will be located. The variance is the spread of the data and determines how wide or narrow the distribution will be. The 
standard deviation is a measure of how much variation there is in the data and determines how much of the data falls within 
certain ranges.

The parameters of the normal distribution also determine the shape of the distribution. The mean and variance determine the 
peak of the distribution, while the standard deviation determines how much of the data falls within certain ranges. The shape 
of a normal distribution is symmetrical, with most of the data points located around the mean and the rest of the data points 
spread out evenly on either side.

"""Q4: Explain the importance of Normal Distribution. Give a few real-life examples of Normal Distribution."""
Ans: Normal Distribution is a type of probability distribution that is symmetrical around the mean, showing that data near the 
mean are more frequent in occurrence than data far from the mean. It is also known as the Gaussian Distribution or Bell Curve.

Normal Distribution is important because it can be used to model and predict the probability of certain outcomes. It is also 
used to measure the variability of data and to determine the probability of an event occurring.

Real-life examples of Normal Distribution include: 
1. Heights of people in a population 
2. Test scores on a standardized test 
3. Blood pressure readings 
4. IQ scores 
5. Weight of items in a manufacturing process 
6. Measurement errors in a scientific experiment

"""Q5: What is Bernaulli Distribution? Give an Example. What is the difference between Bernoulli Distribution and Binomial 
Distribution?"""
Ans:  Bernoulli Distribution is a type of probability distribution that has two possible outcomes, usually labeled as "success"
and "failure". It is a special case of the binomial distribution where n = 1. An example of a Bernoulli Distribution would be 
flipping a coin, where the probability of getting heads is 0.5 and the probability of getting tails is also 0.5.

The difference between Bernoulli Distribution and Binomial Distribution is that Bernoulli Distribution only has two possible 
outcomes, while Binomial Distribution has more than two possible outcomes. Additionally, Bernoulli Distribution is a special case
of Binomial Distribution where n = 1.

In summary, Bernoulli Distribution is a type of probability distribution with two possible outcomes, while Binomial Distribution
is a type of probability distribution with more than two possible outcomes.

"""Q6. Consider a dataset with a mean of 50 and a standard deviation of 10. If we assume that the dataset is normally 
distributed, what is the probability that a randomly selected observation will be greater than 60? Use the appropriate formula 
and show your calculations."""
Ans: P(X > 60) = 1 - P(X ≤ 60)

P(X ≤ 60) = (60 - 50)/10 = 0.67

Therefore, P(X > 60) = 1 - 0.67 = 0.33

Therefore, the probability that a randomly selected observation will be greater than 60 is 0.33.

"""Q7: Explain uniform Distribution with an example."""
Ans: Uniform distribution is a type of probability distribution in which all outcomes are equally likely. An example of a 
uniform distribution is the roll of a fair die. Each side of the die has an equal chance of being rolled, so each outcome 
(1, 2, 3, 4, 5, or 6) has an equal probability of 1/6.

Another example of a uniform distribution is the toss of a fair coin. Each side of the coin has an equal chance of being 
tossed, so each outcome (heads or tails) has an equal probability of 1/2.

"""Q8: What is the z score? State the importance of the z score."""
Ans: The z score is a measure of how many standard deviations a given data point is from the mean of a data set. It is important 
because it allows us to compare different data points to each other and to the mean, and it can be used to calculate probabilities.

For example, if a data point has a z score of 1.5, it is 1.5 standard deviations away from the mean. This can be used to 
calculate the probability that a data point will fall within a certain range of values.

"""Q9: What is Central Limit Theorem? State the significance of the Central Limit Theorem."""
Ans: The Central Limit Theorem states that the sampling distribution of the sample means approaches a normal distribution as 
the sample size increases, regardless of the shape of the population distribution. This theorem is significant because it 
allows us to make inferences about a population based on a sample, even if we don't know the exact shape of the population 
distribution. It also allows us to use the normal distribution to approximate other distributions, such as the binomial and 
Poisson distributions.

The Central Limit Theorem is also important because it allows us to use the normal distribution to calculate probabilities and 
confidence intervals for sample means. This is especially useful in hypothesis testing, where we can use the normal distribution
to calculate the probability of obtaining a sample mean that is significantly different from the population mean.

"""Q10: State the assumptions of the Central Limit Theorem."""
Ans: 
1. The sample size is large enough (n > 30).
2. The population from which the sample is drawn is normally distributed or the sample size is large enough that the Central Limit Theorem applies regardless of the population distribution.
3. The samples are independent of each other.
4. The sample means are independent of each other.
